# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 4.21e-02
# Loss: 927.997, Residuals: -0.003
# Loss: 927.947, Residuals: -0.004
# Optimization terminated successfully.
# Evidence 2949.689
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 3.84e-02
# Loss: 929.152, Residuals: -0.007
# Loss: 925.959, Residuals: -0.005
# Optimization terminated successfully.
# Evidence 2966.885
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 3.05e-02
# Loss: 939.629, Residuals: -0.004
# Optimization terminated successfully.
# Evidence 2972.067
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 3.04e-02
# Loss: 940.547, Residuals: 0.000
# Loss: 940.034, Residuals: 0.001
# Loss: 939.133, Residuals: 0.001
# Loss: 937.406, Residuals: 0.000
# Loss: 934.954, Residuals: -0.004
# Loss: 934.950, Residuals: -0.004
# Optimization terminated successfully.
# Evidence 2978.046
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 2.89e-02
# Loss: 938.632, Residuals: -0.016
# Loss: 938.254, Residuals: -0.012
# Loss: 937.602, Residuals: -0.014
# Loss: 936.718, Residuals: -0.018
# Loss: 935.065, Residuals: -0.019
# Loss: 935.033, Residuals: -0.020
# Optimization terminated successfully.
# Evidence 2985.061
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 2.61e-02
# Loss: 934.017, Residuals: -0.029
# Loss: 933.890, Residuals: -0.028
# Optimization terminated successfully.
# Evidence 2995.733
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 1.83e-02
# Loss: 941.072, Residuals: -0.029
# Optimization terminated successfully.
# Evidence 2999.162
# Updating hyper-parameters...
# Total samples: 188, Updated regularization: 1.82e-02
# Loss: 941.180, Residuals: -0.029
# Optimization terminated successfully.
# Evidence 2999.506
# Pass count  1

# %%
# list of parameter names 
param_names = []
for s1 in species:
    for s2 in species:
        param_names += [s1+"*"+s2]
param_names = list(species) + param_names

# plot parameter distribution
n_species = len(species)
Avec = model.params[n_species:]
Aij_std = np.sqrt(np.diag(model.Ainv))[n_species:]

# %%
plt.figure(figsize=(18,18))
# set counter for parameter std. 
k = 0

for i in range(n_species):
    for j in range(n_species):
        plt.subplot(n_species, n_species, k+1)
        a = np.linspace(Avec[k]-np.std(Avec), Avec[k]+np.std(Avec))
        plt.plot(a, norm.pdf(a,Avec[k],Aij_std[k]))
        plt.axvline(x=0, c='k', alpha=.5)
        k += 1
        if j == 0:
            plt.ylabel(species[i], fontsize=18)
        if i == n_species-1:
            plt.xlabel(species[j], fontsize=18)
        #plt.xlim([-2,2])

plt.suptitle('passage 35', fontsize=24)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig(f"params/p35/P35.pdf")
plt.show()
plt.close()

# compute Wald test for each parameter
std_errors = np.sqrt(np.diag(model.Ainv))
walds = model.params/std_errors
wald_p_vals = 2*norm.cdf(-np.abs(walds))

# save to df 
df = pd.DataFrame()
df["Param name"] = param_names
df["Param value"] = model.params
df["Param stdv"]  = np.sqrt(np.diag(model.Ainv))
df["Param p-value"] = wald_p_vals
for j, param_name in enumerate(param_names):
    df[param_name]  = model.Ainv[:, j]
df.to_csv(f"params/p35/P35.csv", index=False)
# Out:
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]
# /tmp/ipykernel_10164/1638242189.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[param_name]  = model.Ainv[:, j]

# %%
df
# Out:
#     Param name  Param value  Param stdv  Param p-value        CD        DP
# 0           CD     5.078734    0.932564   5.151903e-08  0.869677 -0.006348  \
# 1           DP     0.383168    0.076864   6.195045e-07 -0.006348  0.005908
# 2           CA    -0.501466    0.170251   3.224834e-03 -0.005629  0.000054
# 3           PC    -0.853863    0.304886   5.100897e-03  0.045953  0.001426
# 4           CS    -0.791192    0.131740   1.905142e-09 -0.000035  0.000058
# ..         ...          ...         ...            ...       ...       ...
# 105      EL*CH    20.926605    5.944832   4.313291e-04  0.546363 -0.001395
# 106      EL*BU     0.414961    0.299805   1.663267e-01  0.002865 -0.000060
# 107      EL*BT    -1.758153    0.525522   8.212375e-04 -0.008363 -0.000106
# 108      EL*PV    -0.592941    0.376660   1.154394e-01 -0.001551 -0.000074
# 109      EL*EL   -12.739806    3.483713   2.552223e-04 -0.083327 -0.000827
#
#            CA        PC        CS        CH  ...     EL*CD     EL*DP
# 0   -0.005629  0.045953 -0.000035  0.115942  ... -0.004947  0.000109  \
# 1    0.000054  0.001426  0.000058 -0.001090  ...  0.000008 -0.000019
# 2    0.028985 -0.000165 -0.000340 -0.002035  ...  0.000516 -0.000127
# 3   -0.000165  0.092956 -0.003685  0.002161  ...  0.000275  0.000229
# 4   -0.000340 -0.003685  0.017356  0.000982  ...  0.000590  0.000016
# ..        ...       ...       ...       ...  ...       ...       ...
# 105 -0.010105  0.035740 -0.010566 -1.500380  ... -0.016886  0.061862
# 106 -0.000369  0.000668 -0.000258 -0.010631  ...  0.011915  0.008373
# 107  0.000284 -0.000149  0.000897  0.026263  ...  0.037189  0.009190
# 108 -0.000100  0.000155  0.000120  0.006396  ... -0.007181  0.010120
# 109  0.004380 -0.004777  0.007818  0.291263  ...  0.086555  0.008998
#
#         EL*CA     EL*PC     EL*CS      EL*CH     EL*BU     EL*BT     EL*PV
# 0    0.004138 -0.021733  0.003993   0.546363  0.002865 -0.008363 -0.001551  \
# 1   -0.000270 -0.000602 -0.000178  -0.001395 -0.000060 -0.000106 -0.000074
# 2   -0.010900 -0.000070 -0.001318  -0.010105 -0.000369  0.000284 -0.000100
# 3    0.000606 -0.047699  0.000983   0.035740  0.000668 -0.000149  0.000155
# 4    0.000697  0.012843 -0.000423  -0.010566 -0.000258  0.000897  0.000120
# ..        ...       ...       ...        ...       ...       ...       ...
# 105 -2.342782 -2.322575  0.362611  35.341034  0.746463 -1.431489 -0.326249
# 106 -0.042413 -0.030502  0.040446   0.746463  0.089883 -0.022486  0.003203
# 107  0.174450  0.200756  0.028096  -1.431489 -0.022486  0.276174  0.040875
# 108  0.072813  0.071365  0.067823  -0.326249  0.003203  0.040875  0.141873
# 109  1.757895  1.799058  0.007999 -17.447943 -0.428718  1.089712  0.320306
#
#          EL*EL
# 0    -0.083327
# 1    -0.000827
# 2     0.004380
# 3    -0.004777
# 4     0.007818
# ..         ...
# 105 -17.447945
# 106  -0.428718
# 107   1.089712
# 108   0.320306
# 109  12.136257
#
# [110 rows x 114 columns]
